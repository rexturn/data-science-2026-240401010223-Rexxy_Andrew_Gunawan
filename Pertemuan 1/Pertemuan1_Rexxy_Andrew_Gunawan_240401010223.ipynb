# %% [markdown]
# # Hands-on Sesi 1
#
# > Topik: Pengantar Python untuk Data Science - Output, Variabel, List, Fungsi
#
# Nama Lengkap : Rexxy Andrew Gunawan
#
# NIM          : 240401010223
#
# Kelas        : IF403
#
# Program Studi: S1 PJJ Informatika UNSIA
#
# Mata Kuliah  : Data Science
#
# Disusun oleh : Rexxy Andrew Gunawan

# %% [markdown]
# Link Google Colab: https://colab.research.google.com/drive/12jhO-Cmfp_PdrKIwMbI1ldO_bFbfEj6O?usp=sharing

# %% [markdown]
# # 1. Output sederhana

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# # 2. Variabel dan tipe data dasar

# %%
nama = "Rexxy Andrew Gunawan" # String
angkatan = 2024 # Integer
ipk = 4.00 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Rexxy Andrew Gunawan
# Angkatan : 2024
# IPK : 4.0
# Aktif : True

# %% [markdown]
# # 3. List dan perulangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "Github"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. Github

# %% [markdown]
# # 4. Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Rexxy Andrew Gunawan", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Rexxy Andrew Gunawan dari Informatika, angkatan 2024.

# %% [markdown]
# # Kesimpulan Sesi Pembelajaran Sesi 1
#
#
# *   Apa yang telah dipelajari: Saya telah mempraktikkan dasar pemrograman Python (meliputi penggunaan **variabel**, **list**, **perulangan**, dan **fungsi**) menggunakan Google Colab, serta belajar cara mendokumentasikan dan mengunggah hasil pekerjaan tersebut ke repositori GitHub sebagai portofolio.
#
# *   Temuan utama: Penggunaan Google Colab sangat memudahkan proses penulisan kode secara interaktif tanpa perlu instalasi lokal, dan GitHub terbukti sangat berguna untuk melacak riwayat pengerjaan proyek secara sistematis.
#
# *   Keterbatasan/Pertanyaan: Praktik kali ini masih terbatas pada logika dasar pemrograman; saya masih perlu mempelajari lebih lanjut bagaimana menerapkan fungsi Python yang lebih kompleks untuk mengolah data nyata di pertemuan-pertemuan berikutnya.
